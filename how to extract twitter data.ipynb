# %%
# !pip install tweepy

# %%
import tweepy 
import pandas as pd

# %%
consumer_key = "HfSVW6KJsxafE7koSJ1J9dwL5"
consumer_secret = "zyfpsiiKzkW1VCCgdjxHUva4CpVq1G8786Ab14eMH7N8BmqPJ3"
access_token = "1419916858317103104-sJCWiwC9uPUpv58SUiBDkzQODsJbnS"
access_token_secret = "evLH3pm6GiZqOWOBqOLBXROzyBOxP6ClQZwWELqsVQJd0"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
n = 500 
tweets = []
likes = []
time = []
geo = []
lang = []
entities = []


for i in tweepy.Cursor(api.search, q="COVID-19", tweet_mode = "extended").items(n):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    geo.append(i.geo)
    lang.append(i.lang)
    entities.append(i.entities)

# %%
df = pd.DataFrame({'tweets':tweets,'likes':likes,'time':time,'geo':geo,'lang':lang,'entities':entities})

# %%
df
# Out:
#                                                 tweets  likes  \
# 0    RT @PatStarSharing: 🎁 PPPAT STAR SHARING QIXI ...      0
# 1    RT @BreannaMorello: 63 people have tested posi...      0
# 2    RT @amethystarlight: It’s a dark summer in Iow...      0
# 3    RT @LalobaRose: #Covid19 : l’#UE se penche sur...      0
# 4    RT @eraxarticuno: Dr Zaw Myint Maung, a prime ...      0
# ..                                                 ...    ...
# 495  RT @iran_policy: Iran News in Brief – August 1...      0
# 496  RT @erikhalvorsen18: NC GOP Rep. Keith Kidwell...      0
# 497  RT @SaveMM99: Today,At least 10 innocent civil...      0
# 498  RT @cnni: Florida reported a new record number...      0
# 499  RT @therosesloves: Semoga kita semua dimurahka...      0
#
#                    time   geo lang  \
# 0   2021-08-14 14:11:04  None   th
# 1   2021-08-14 14:11:04  None   en
# 2   2021-08-14 14:11:04  None   en
# 3   2021-08-14 14:11:04  None   fr
# 4   2021-08-14 14:11:04  None   en
# ...
